# %% [markdown]
# # Module: Analyzing Business Problems
# ## Sprint: Product Analyst
# ## Part 3: Graded task
#
# Tips and example of project solution can be found [here](https://docs.google.com/document/d/1wfZeB6yzjq17cXYCm7XgS53f1knssK3cZIpnzdB0Z44/edit)
